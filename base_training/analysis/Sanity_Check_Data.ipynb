# %%
D:\English_Results

# %%
import pandas as pd
check2 = pd.read_parquet("D:\English_Results\embeddings_2000.parquet")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\danielyoon\AppData\Local\Temp\ipykernel_40956\3951034006.py:2: SyntaxWarning: invalid escape sequence '\E'
#   check2 = pd.read_parquet("D:\English_Results\embeddings_2000.parquet")

# %%
check2
# Out:
#          original_index      subset_source  row_idx  \
# 0       US-58863600-A_1   subset_1.parquet        0
# 1       US-47985300-A_1   subset_1.parquet        1
# 2             1113182_1   subset_1.parquet        2
# 3       US-60370700-A_1   subset_1.parquet        3
# 4       US-49704000-A_1   subset_1.parquet        4
# ...                 ...                ...      ...
# 403307  US-55914400-A_3  subset_99.parquet     4024
# 403308        6470927_1  subset_99.parquet     4025
# 403309        1743339_1  subset_99.parquet     4026
# 403310  US-81904700-A_2  subset_99.parquet     4027
# 403311  US-58713600-A_2  subset_99.parquet     4028
#
#                                                 embedding
# 0       [0.01119, 0.015, 0.006977, -0.0001404, 0.00085...
# 1       [-0.007534, 0.01633, 0.004856, -0.018, 0.00875...
# 2       [-0.003828, 0.001009, 0.0218, 0.0004838, -0.06...
# 3       [0.01282, 0.02943, 0.01854, 0.005737, -0.03348...
# ...

# %%
import pandas as pd
check = pd.read_parquet("D:\English_Results\embeddings_1678.parquet")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\danielyoon\AppData\Local\Temp\ipykernel_172416\3138069953.py:2: SyntaxWarning: invalid escape sequence '\E'
#   check = pd.read_parquet("D:\English_Results\embeddings_1678.parquet")

# %%
check
# Out:
#                                          original_index      subset_source  \
# 0                          thelivelyoracles00alleuoft_7   subset_1.parquet
# 1                           diaryconsultatio72781madr_6   subset_1.parquet
# 2     bim_early-english-books-1641-1700_an-apology-f...   subset_1.parquet
# 3                           diaryconsultatio5584madr_12   subset_1.parquet
# 4                            diaryconsultatio1721madr_1   subset_1.parquet
# ...                                                 ...                ...
# 8176                        diaryconsultatio5381madr_25  subset_99.parquet
# 8177  bim_early-english-books-1641-1700_mr-wingates-...  subset_99.parquet
# 8178  bim_early-english-books-1641-1700_the-new-poli...  subset_99.parquet
# 8179                          meditationsupono00grew_26  subset_99.parquet
# 8180  bim_early-english-books-1641-1700_a-collection...  subset_99.parquet
#
#       row_idx                                          embedding
# ...

# %%
pd.read_parquet("D:\English_Classified\classified_1720.parquet")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\danielyoon\AppData\Local\Temp\ipykernel_49232\2659855373.py:1: SyntaxWarning: invalid escape sequence '\E'
#   pd.read_parquet("D:\English_Classified\classified_1720.parquet")
#                                              identifier  predicted_quality  \
# 0     bim_eighteenth-century_fifty-two-practical-dis...           1.874804
# 1                             worksoffamousnic00mach_46           1.928561
# 2     bim_eighteenth-century_magna-britannia-et-hibe...           2.048666
# 3     bim_eighteenth-century_the-history-of-herodotu...           1.553227
# 4     bim_eighteenth-century_essays-upon-several-mor...           1.913582
# ...                                                 ...                ...
# 4612  bim_eighteenth-century_the-book-of-common-pray...           1.787807
# 4613           Philosophical-Transactions-vol-30_1720_9           1.976793
# ...

# %%
pd.read_parquet(r"D:\English\1678\subset_1.parquet")
# Out:
#                                            identifier   collection  \
# 0                        thelivelyoracles00alleuoft_7  US-PD-Books
# 1                         diaryconsultatio72781madr_6   English-PD
# 2   bim_early-english-books-1641-1700_an-apology-f...   English-PD
# 3                         diaryconsultatio5584madr_12   English-PD
# 4                          diaryconsultatio1721madr_1   English-PD
# ..                                                ...          ...
# 79  bim_early-english-books-1641-1700_decameron-ph...   English-PD
# 80  bim_early-english-books-1641-1700_the-lightnin...   English-PD
# 81  bim_early-english-books-1641-1700_the-new-worl...   English-PD
# 82  bim_early-english-books-1641-1700_several-disc...   English-PD
# 83  bim_early-english-books-1641-1700_an-alarme-to...   English-PD
#
#        open_type        license                      date  \
# 0   Open Culture  Public Domain 1678-01-01 00:00:00+00:00
# ...
