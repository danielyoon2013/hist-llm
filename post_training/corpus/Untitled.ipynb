# %%
import pandas as pd

pd.read_parquet(r"C:\Users\danielyoon\Dropbox\hist_LLM\Data\additional_data\news_archives\Economist\economist_2014-1129.parquet")["ocr_text"][10]
# Out:
# 'Attack of the cybermen\n\t\t\tComputer spying\n\t\t\tSophisticated viruses will be the workhorses of 21st-century spying. But there should be rules\n\t\t\treply “because that’s where the secrets are”. As the world has gone digital, spying has, too. Regin is just the latest in a trend that first came to public notice in 2010, when a piece of American and Israeli software called Stuxnet was revealed to have been responsible for sabotaging part of Iran’s nuclear programme. Since then have come Flame, Red October, DarkHotel and others (see page 65); more surely lurk undiscovered in the world’s networks. But unlike the indis- criminate surveillance revealed by Edward Snowden, these chunks of malware seem, like traditional spying, to be targeted at specific governments or even individuals. For spies, such digital espionage has advantages over the shoe-leather sort. Computers are stuffed with data that can be copied and beamed around the world in seconds-so much easier than fiddling with m
# ...

# %%
pd.read_parquet(r"C:\Users\danielyoon\Dropbox\hist_LLM\Data\additional_data\news_archives\FT\2006.parquet")["text"]
# Out:
# 0                        SINAN TIMES TUESDAY JANUARY 3 2006
# 1         Windows PCs face 'huge' virus threat Computer ...
# 2         NATIONAL NEWS 2-6 LEADE/LETTERS 18 WORLD NEWS ...
# 3         GTHE bns t b . TUBS UITEO2W6 No 3A96*1 'I* Fmw...
# 4         VMr TusncnrO, Wfno fQeaurai e umm Hos K s r g ...
#                                 ...
# 253784    2007? The bond market plainly believes that it...
# 253785    Swanson of MSS points out that a year-on-year ...
# 253786    answers look very plausible then you have reas...
# 253787    East and for the supply of oil would be horren...
# 253788    WDE ~Lt* How to use Simple High Profit, Low ri...
# Name: text, Length: 253789, dtype: object

# %%
pd.read_parquet(r"C:\Users\danielyoon\Dropbox\hist_LLM\Data\additional_data\news_archives\NYT\nyt_2017.parquet")["combined_text"][600]
# Out:
# "How ‘Bambi’ Got Its Look From 1,000-Year-Old Chinese Art\n\nThe Chinese-American artist Tyrus Wong blended 1000-year-old painting techniques with his own sensibility to create the film's signature style."

# %%
pd.read_parquet(r"C:\Users\danielyoon\Dropbox\hist_LLM\Data\additional_data\news_archives\NYT\nyt_2016.parquet")["combined_text"][600]
# Out:
# 'Ted Cruz&#8217;s Iowa Bus Tour: Making a Favorite Joke in Boone\n\nStop No.1 on Ted Cruz’s 28-town swing of Iowa features a favorite joke.'

# %%
pd.read_parquet(r"C:\Users\danielyoon\Dropbox\hist_LLM\Data\additional_data\news_archives\WSJ\wsj_articles.parquet")["abstract"][0]
# Out:
# 'The bull market of 1885 began July 2, with the average price of 12 active stocks 61.49.'

# %%
import json

with open(f, 'r', encoding='utf-8') as k:
    data = json.load(k)

# Check the type and print the first 2 items
if isinstance(data, list):
    for item in data[:2]: 
        print(json.dumps(item, indent=4))
else:
    # If it's a giant dictionary, print just the keys
    print(data.keys())
# Out:
# {
# ...

# %%
import json
f = r"C:\Users\danielyoon\Dropbox\hist_LLM\Data\additional_data\newswire\1977_data_clean.json"
a
with open(f) as k:
    d = json.load(k)
    print(d)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
pd.read_parquet(r"C:\Users\danielyoon\Dropbox\hist_LLM\Data\additional_data\newswire\1977_data_clean.

# %%
x = pd.read_parquet(r"C:\Users\danielyoon\Dropbox\hist_LLM\Data\additional_data\news_archives\NYT\nyt_2017.parquet")

# %%
x["combined_text"][4]
# Out:
# 'Treasury Auctions Set for the Week of Jan. 2\n\nThe following tax-exempt fixed-income issues are scheduled for pricing this week.'
